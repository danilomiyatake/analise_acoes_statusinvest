# %% [markdown]
# # 1. Webscraping e criação do DataFrame

# %% [markdown]
# ## Importando bibliotecas e arquivos

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
lista_empresa = pd.read_csv('lista_empresa.csv', sep=';')

# %%
ticks = list(lista_empresa['codigo'])
ticks = [tick.lower() for tick in ticks]
ticks
# Out:
# ['aalr3',
#  'abcb4',
#  'abev3',
#  'aeri3',
#  'aesb3',
#  'aflt3',
#  'agro3',
#  'agxy3',
#  'aheb3',
#  'aheb5',
#  'aheb6',
#  'alld3',
#  'alpa3',
#  'alpa4',
#  'alpk3',
#  'also3',
#  'alup11',
#  'alup3',
#  'alup4',
#  'amar3',
#  'ambp3',
#  'amer3',
#  'anim3',
#  'aper3',
#  'apti4',
#  'arml3',
#  'arzz3',
#  'asai3',
#  'atmp3',
#  'atom3',
#  'aure3',
#  'avll3',
#  'azev3',
#  'azev4',
#  'azul4',
#  'b3sa3',
#  'bahi3',
#  'balm3',
#  'balm4',
#  'bauh4',
#  'baza3',
#  'bbas11',
#  'bbas3',
#  'bbdc3',
#  'bbdc4',
#  'bbse3',
#  'bdll3',
#  'bdll4',
#  'beef3',
#  'bees3',
#  'bees4',
#  'bgip3',
#  'bgip4',
#  'bidi11',
#  'bidi12',
#  'bidi3',
#  'bidi4',
#  'biom3',
#  'bkbr3',
#  'blau3',
#  'blut3',
#  'blut4',
#  'bmeb3',
#  'bmeb4',
#  'bmgb4',
#  'bmin3',
#  'bmin4',
#  'bmks3',
#  'bmob3',
#  'bnbr3',
#  'boas3',
#  'bobr3',
#  'bobr4',
#  'bpac11',
#  'bpac3',
#  'bpac5',
#  'bpan4',
#  'bpar3',
#  'brap3',
#  'brap4',
#  'brbi11',
#  'brfs3',
#  'brge11',
#  'brge12',
#  'brge3',
#  'brge5',
#  'brge6',
#  'brge7',
#  'brge8',
#  'brit3',
#  'briv3',
#  'briv4',
#  'brkm3',
#  'brkm5',
#  'brkm6',
#  'brml3',
#  'brpr3',
#  'brsr3',
#  'brsr5',
#  'brsr6',
#  'bsli3',
#  'bsli4',
#  'cali3',
#  'cali4',
#  'camb3',
#  'caml3',
#  'card3',
#  'cash3',
#  'casn3',
#  'casn4',
#  'cbav3',
#  'cbee3',
#  'ccro3',
#  'ceab3',
#  'cebr3',
#  'cebr5',
#  'cebr6',
#  'cedo3',
#  'cedo4',
#  'ceeb3',
#  'ceeb5',
#  'ceed3',
#  'ceed4',
#  'cegr3',
#  'cepe3',
#  'cepe5',
#  'cepe6',
#  'cgas3',
#  'cgas5',
#  'cgra3',
#  'cgra4',
#  'ciel3',
#  'clsa3',
#  'clsc3',
#  'clsc4',
#  'cmig3',
#  'cmig4',
#  'cmin3',
#  'coce3',
#  'coce5',
#  'coce6',
#  'cogn3',
#  'corr3',
#  'corr4',
#  'cpfe3',
#  'cple11',
#  'cple3',
#  'cple5',
#  'cple6',
#  'crde3',
#  'crfb3',
#  'criv3',
#  'criv4',
#  'crpg3',
#  'crpg5',
#  'crpg6',
#  'csab3',
#  'csab4',
#  'csan3',
#  'csed3',
#  'csmg3',
#  'csna3',
#  'csrn3',
#  'csrn5',
#  'csrn6',
#  'csud3',
#  'ctka3',
#  'ctka4',
#  'ctnm3',
#  'ctnm4',
#  'ctsa3',
#  'ctsa4',
#  'cury3',
#  'cvcb3',
#  'cxse3',
#  'cyre3',
#  'dasa3',
#  'desk3',
#  'dexp3',
#  'dexp4',
#  'dirr3',
#  'dmfn3',
#  'dmmo3',
#  'dmvf3',
#  'dohl3',
#  'dohl4',
#  'dotz3',
#  'dtcy3',
#  'dxco3',
#  'ealt3',
#  'ealt4',
#  'ecor3',
#  'eeel3',
#  'eeel4',
#  'egie3',
#  'ektr3',
#  'ektr4',
#  'elet3',
#  'elet5',
#  'elet6',
#  'elmd3',
#  'emae3',
#  'emae4',
#  'embr3',
#  'enat3',
#  'enbr3',
#  'enev3',
#  'engi11',
#  'engi3',
#  'engi4',
#  'enju3',
#  'enmt3',
#  'enmt4',
#  'epar3',
#  'eqma3b',
#  'eqpa3',
#  'eqpa5',
#  'eqpa6',
#  'eqpa7',
#  'eqtl3',
#  'espa3',
#  'estr3',
#  'estr4',
#  'eter3',
#  'euca3',
#  'euca4',
#  'even3',
#  'eztc3',
#  'fesa3',
#  'fesa4',
#  'fher3',
#  'fige3',
#  'fige4',
#  'fiqe3',
#  'flry3',
#  'fncn3',
#  'fras3',
#  'frio3',
#  'frta3',
#  'gepa3',
#  'gepa4',
#  'gett11',
#  'gett3',
#  'gett4',
#  'gfsa3',
#  'ggbr3',
#  'ggbr4',
#  'ggps3',
#  'gmat3',
#  'goau3',
#  'goau4',
#  'goll4',
#  'gpar3',
#  'grnd3',
#  'gshp3',
#  'guar3',
#  'haga3',
#  'haga4',
#  'hapv3',
#  'hbor3',
#  'hbre3',
#  'hbsa3',
#  'hbts5',
#  'heta3',
#  'heta4',
#  'hoot4',
#  'hype3',
#  'ifcm3',
#  'igbr3',
#  'igti11',
#  'igti3',
#  'igti4',
#  'inep3',
#  'inep4',
#  'irbr3',
#  'itsa3',
#  'itsa4',
#  'itub3',
#  'itub4',
#  'jall3',
#  'jbss3',
#  'jfen3',
#  'jhsf3',
#  'jopa3',
#  'jopa4',
#  'jslg3',
#  'kepl3',
#  'klbn11',
#  'klbn3',
#  'klbn4',
#  'krsa3',
#  'land3',
#  'lavv3',
#  'lcam3',
#  'leve3',
#  'ligt3',
#  'lipr3',
#  'ljqq3',
#  'llis3',
#  'logg3',
#  'logn3',
#  'lpsb3',
#  'lren3',
#  'lupa3',
#  'luxm3',
#  'luxm4',
#  'lvtc3',
#  'lwsa3',
#  'mapt3',
#  'mapt4',
#  'matd3',
#  'mbly3',
#  'mdia3',
#  'mdne3',
#  'meal3',
#  'mega3',
#  'melk3',
#  'merc3',
#  'merc4',
#  'mgel3',
#  'mgel4',
#  'mglu3',
#  'mils3',
#  'mlas3',
#  'mmxm11',
#  'mmxm3',
#  'mndl3',
#  'mnpr3',
#  'moar3',
#  'modl11',
#  'modl3',
#  'modl4',
#  'movi3',
#  'mrfg3',
#  'mrsa3b',
#  'mrsa5b',
#  'mrsa6b',
#  'mrve3',
#  'mspa3',
#  'mspa4',
#  'mtig3',
#  'mtig4',
#  'mtre3',
#  'mtsa3',
#  'mtsa4',
#  'mult3',
#  'mwet3',
#  'mwet4',
#  'rail3',
#  'raiz4',
#  'rani3',
#  'rapt3',
#  'rapt4',
#  'rcsl3',
#  'rcsl4',
#  'rdni3',
#  'rdor3',
#  'recv3',
#  'rede3',
#  'rent3',
#  'rnew11',
#  'rnew3',
#  'rnew4',
#  'romi3',
#  'rpad3',
#  'rpad5',
#  'rpad6',
#  'rpmg3',
#  'rrrp3',
#  'rsid3',
#  'rsul4',
#  'sanb11',
#  'sanb3',
#  'sanb4',
#  'sapr11',
#  'sapr3',
#  'sapr4',
#  'sbfg3',
#  'sbsp3',
#  'scar3',
#  'seer3',
#  'seql3',
#  'sgps3',
#  'show3',
#  'shul3',
#  'shul4',
#  'simh3',
#  'slce3',
#  'sled3',
#  'sled4',
#  'smft3',
#  'smto3',
#  'snsy3',
#  'snsy5',
#  'snsy6',
#  'soja3',
#  'soma3',
#  'sond3',
#  'sond5',
#  'sond6',
#  'sqia3',
#  'stbp3',
#  'sula11',
#  'sula3',
#  'sula4',
#  'suzb3',
#  'syne3',
#  'taee11',
#  'taee3',
#  'taee4',
#  'tasa3',
#  'tasa4',
#  'tcno3',
#  'tcno4',
#  'tcsa3',
#  'tecn3',
#  'teka3',
#  'teka4',
#  'telb3',
#  'telb4',
#  'tend3',
#  'tfco4',
#  'tgma3',
#  'tims3',
#  'tkno3',
#  'tkno4',
#  'tots3',
#  'tpis3',
#  'trad3',
#  'tris3',
#  'trpl3',
#  'trpl4',
#  'tten3',
#  'tupy3',
#  'txrx3',
#  'txrx4',
#  'ucas3',
#  'ugpa3',
#  'unip3',
#  'unip5',
#  'unip6',
#  'usim3',
#  'usim5',
#  'usim6',
#  'vale3',
#  'vamo3',
#  'vbbr3',
#  'viia3',
#  'vitt3',
#  'viva3',
#  'vivr3',
#  'vivt3',
#  'vlid3',
#  'vspt3',
#  'vulc3',
#  'vveo3',
#  'wege3',
#  'west3',
#  'whrl3',
#  'whrl4',
#  'wizs3',
#  'wlmm3',
#  'wlmm4',
#  'yduq3',
#  'zamp3']

# %% [markdown]
# ## Funções

# %% [markdown]
# ### Verificando se o tick é válido

# %%
def validando_tick(tick):
    url_base = f'https://statusinvest.com.br/acoes/{tick}'

    headers = {
        'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
    }

    response = str(requests.get(url_base, headers = headers))
    
    if response == '<Response [200]>':
        return True
    else:
        return False

# %%
#Testando a função
print(validando_tick('abev3'))
# Out:
# True

# %% [markdown]
# ### Substituindo caracteres indesejados

# %%
dic = {
    '.': '',
    ',': '.',
    '%': '',
}

# %%
def substituir_caracter(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text.strip()

# %% [markdown]
# ## Abrindo a página

# %% [markdown]
# ```python
# url_base = f'https://statusinvest.com.br/acoes/{tick}'
#
# headers = {
#     'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
# }
#
# response_text = requests.get(url_base, headers = headers).text
#
# soup = BeautifulSoup(response_text, 'lxml')
# ```

# %% [markdown]
# ## Coletando dados gerais da empresa

# %% [markdown]
# ```python
# nome_empresa = soup.find('h4', {'class': 'mb-2 mt-0 fs-4'}).span.text
# cnpj = soup.find('h4', {'class': 'mb-2 mt-0 fs-4'}).small.text
#
# segmentos = soup.find('div', {'class' : 'card bg-main-gd-h white-text rounded ov-hidden pt-0 pb-'}).find_all('strong',{'class':'value'})
#
# setor_atuacao = segmentos[0].text
# subsetor_atuacao = segmentos[1].text
# segmento_atuacao = segmentos[2].text
#
# valores = soup.find('div', {'class': 'top-info info-3 sm d-flex justify-between mb-3'}).find_all('strong', {'class' : 'value'})
#
# patrimonio_liquido = (valores[0].text.replace('.','').replace(',','.').strip())
# ativos = (valores[1].text.replace('.','').replace(',','.').strip())
# ativo_circulante = (valores[2].text.replace('.','').replace(',','.').strip())
# divida_bruta = (valores[3].text.replace('.','').replace(',','.').strip())
# disponibilidade = (valores[4].text.replace('.','').replace(',','.').strip())
# divida_liquida = (valores[5].text.replace('.','').replace(',','.').strip())
# valor_de_mercado = (valores[6].text.replace('.','').replace(',','.').strip())
# valor_de_firma = (valores[7].text.replace('.','').replace(',','.').strip())
# num_total_papeis = (valores[8].text.replace('.','').replace(',','.').strip())
# segmento_listagem = valores[9].text
# free_float = (valores[10].text.replace('%','').replace(',','.').strip())
# ```

# %% [markdown]
# Deixando o código menos repetitivo
#
# ```python
#
# valores = soup.find('div', {'class': 'top-info info-3 sm d-flex justify-between mb-3'}).find_all('strong', {'class' : 'value'})
#
# dados_gerais_empresa = ['patrimonio_liquido', 'ativos', 'ativo_circulante', 'divida_bruta', 'disponibilidade', 'divida_liquida', 'valor_de_mercado', 'valor_de_firma', 'num_total_papeis', 'segmento_listagem', 'free_float']
#
# dic_empresa = {}
#
# for i in range(len(dados_gerais_empresa)):
#     dic_empresa[dados_gerais_empresa[i]] = substituir_caracter(valores[i].text, dic)
# ```

# %% [markdown]
# ## Coletando dados gerais do papel

# %% [markdown]
# ```python
# info_preco = soup.find('div', {'class': 'pb-3 pb-md-5'}).find_all('strong', {'class':'value'})
#
# cotacao_atual = (info_preco[0].text.replace(',','.'))
# min_52_sem = (info_preco[1].text.replace(',','.'))
# max_52_sem = (info_preco[2].text.replace(',','.'))
# dividend_yield = (info_preco[3].text.replace(',','.').replace('%','').replace('-',''))
# valorizacao = (info_preco[4].text.replace(',','.').replace('%',''))
#
# ```

# %% [markdown]
# Deixando o código menos repetitivo
# ```python
# dados_gerais_papel = ['cotacao_atual', 'min_52_sem', 'max_52_sem', 'dividend_yield', 'valorizacao']
# dic_papel = {}
#
# for i in range(len(dados_gerais_papel)):
#     dic_papel[dados_gerais_papel[i]] = substituir_caracter(info_preco[i].text, dic)
# ```

# %% [markdown]
# ## Consolidando em uma função

# %%
def coletando_info(tick):
    
    # Dicionário de caracteres para serem substituidos na função substituir_caracter
    sub_caracteres = {
    '.': '',
    ',': '.',
    '%': '',
    }
    
    if validando_tick(tick):
        
        url_base = f'https://statusinvest.com.br/acoes/{tick}'

        headers = {
            'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36 Edg/108.0.1462.54'
        }

        response_text = requests.get(url_base, headers = headers).text

        soup = BeautifulSoup(response_text, 'lxml')

        segmentos = soup.find('div', {'class' : 'card bg-main-gd-h white-text rounded ov-hidden pt-0 pb-0'}).find_all('strong',{'class':'value'})
        valores = soup.find('div', {'class': 'top-info info-3 sm d-flex justify-between mb-3'}).find_all('strong', {'class' : 'value'})    
        info_preco = soup.find('div', {'class': 'pb-3 pb-md-5'}).find_all('strong', {'class':'value'})
        
        info = {'Papel': tick }
        
        info['Empresa'] = soup.find('h4', {'class': 'mb-2 mt-0 fs-4'}).span.text
        info['CNPJ'] = soup.find('h4', {'class': 'mb-2 mt-0 fs-4'}).small.text
        
        dados_segmentos = ['Setor de atuação', 'Subsetor de atuação', 'Segmento de atuação']
                    
        dados_gerais_empresa = ['Patrimônio líquido', 'Ativos', 'Ativo circulante', 
                                'Dívida bruta', 'Disponibilidade', 'Dívida líquida', 
                                'Valor de mercado', 'Valor de firma', 'Número total de papéis',
                                'Segmento de listagem', 'Free float']
        
        dados_gerais_papel = ['Cotação atual', 'Mínima 52 semanas', 'Máxima 52 semanas', 
                              'Dividend Yield', 'Valorização']
       
        for i in range(len(dados_segmentos)):
            info[dados_segmentos[i]] = segmentos[i].text
              
        for i in range(len(dados_gerais_empresa)):
            info[dados_gerais_empresa[i]] = substituir_caracter(valores[i].text, sub_caracteres)
        
        for i in range(len(dados_gerais_papel)):
            info[dados_gerais_papel[i]] = substituir_caracter(info_preco[i].text, sub_caracteres)
        
        return info

# %%
# Testando a função

dados = coletando_info('abev3')
print(dados)
# Out:
# {'Papel': 'abev3', 'Empresa': 'AMBEV S.A.', 'CNPJ': '07.526.557/0001-00', 'Setor de atuação': 'Consumo não Cíclico', 'Subsetor de atuação': 'Bebidas', 'Segmento de atuação': 'Cervejas e Refrigerantes', 'Patrimônio líquido': '90178032000', 'Ativos': '142063954000', 'Ativo circulante': '41556965000', 'Dívida bruta': '2980480000', 'Disponibilidade': '19059870000', 'Dívida líquida': '-16079390000', 'Valor de mercado': '225543105306', 'Valor de firma': '209463715306', 'Número total de papéis': '15750216851', 'Segmento de listagem': '', 'Free float': '27.85', 'Cotação atual': '14.32', 'Mínima 52 semanas': '12.47', 'Máxima 52 semanas': '16.03', 'Dividend Yield': '5.32', 'Valorização': '2.95'}

# %% [markdown]
# ## Coletando dados de múltiplas empresas

# %%
lista_consolidada = []

start_time = time.time()

for tick in ticks:
    dados = coletando_info(tick)
    if dados != None:
        lista_consolidada.append(dados)
        
print(f"Tempo de execução: {round(time.time() - start_time, 4)} segundos")
# Out:
# Tempo de execução: 450.107 segundos

# %%
lista_consolidada
# Out:
# [{'Papel': 'aalr3',
#   'Empresa': 'CENTRO DE IMAGEM DIAGNOSTICOS S.A.',
#   'CNPJ': '42.771.949/0001-35',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Serv.Méd.Hospit..Análises e Diagnósticos',
#   'Segmento de atuação': 'Serv.Méd.Hospit..Análises e Diagnósticos',
#   'Patrimônio líquido': '1145368000',
#   'Ativos': '2573833000',
#   'Ativo circulante': '457827000',
#   'Dívida bruta': '808798000',
#   'Disponibilidade': '240190000',
#   'Dívida líquida': '568608000',
#   'Valor de mercado': '2518454053',
#   'Valor de firma': '3087062053',
#   'Número total de papéis': '118292816',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '35.52',
#   'Cotação atual': '21.29',
#   'Mínima 52 semanas': '12.85',
#   'Máxima 52 semanas': '21.60',
#   'Dividend Yield': '-',
#   'Valorização': '65.68'},
#  {'Papel': 'abcb4',
#   'Empresa': 'BCO ABC BRASIL S.A.',
#   'CNPJ': '28.195.667/0001-06',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '5070725000',
#   'Ativos': '52140478000',
#   'Ativo circulante': '4297215000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '4297215000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '4291190440',
#   'Valor de firma': '4291190440',
#   'Número total de papéis': '226090118',
#   'Segmento de listagem': 'Nível 2',
#   'Free float': '29.88',
#   'Cotação atual': '18.98',
#   'Mínima 52 semanas': '14.47',
#   'Máxima 52 semanas': '22.29',
#   'Dividend Yield': '7.36',
#   'Valorização': '30.00'},
#  {'Papel': 'abev3',
#   'Empresa': 'AMBEV S.A.',
#   'CNPJ': '07.526.557/0001-00',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Bebidas',
#   'Segmento de atuação': 'Cervejas e Refrigerantes',
#   'Patrimônio líquido': '90178032000',
#   'Ativos': '142063954000',
#   'Ativo circulante': '41556965000',
#   'Dívida bruta': '2980480000',
#   'Disponibilidade': '19059870000',
#   'Dívida líquida': '-16079390000',
#   'Valor de mercado': '225543105306',
#   'Valor de firma': '209463715306',
#   'Número total de papéis': '15750216851',
#   'Segmento de listagem': '',
#   'Free float': '27.85',
#   'Cotação atual': '14.32',
#   'Mínima 52 semanas': '12.47',
#   'Máxima 52 semanas': '16.03',
#   'Dividend Yield': '5.32',
#   'Valorização': '2.95'},
#  {'Papel': 'aeri3',
#   'Empresa': 'AERIS IND. E COM. DE EQUIP. GERACAO DE ENERGIA S.A',
#   'CNPJ': '12.528.708/0001-07',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Máq. e Equip. Industriais',
#   'Patrimônio líquido': '942087000',
#   'Ativos': '3459015000',
#   'Ativo circulante': '2285013000',
#   'Dívida bruta': '1573577000',
#   'Disponibilidade': '856392000',
#   'Dívida líquida': '717185000',
#   'Valor de mercado': '819848398',
#   'Valor de firma': '1537033398',
#   'Número total de papéis': '766213456',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '29.64',
#   'Cotação atual': '1.07',
#   'Mínima 52 semanas': '0.88',
#   'Máxima 52 semanas': '6.54',
#   'Dividend Yield': '1.93',
#   'Valorização': '-81.83'},
#  {'Papel': 'aesb3',
#   'Empresa': 'AES BRASIL ENERGIA S.A.',
#   'CNPJ': '37.663.076/0001-07',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '4175175000',
#   'Ativos': '15104672000',
#   'Ativo circulante': '4091868000',
#   'Dívida bruta': '7893505000',
#   'Disponibilidade': '3455382000',
#   'Dívida líquida': '4438123000',
#   'Valor de mercado': '5573846900',
#   'Valor de firma': '10011969900',
#   'Número total de papéis': '601927311',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '52.37',
#   'Cotação atual': '9.26',
#   'Mínima 52 semanas': '9.05',
#   'Máxima 52 semanas': '12.06',
#   'Dividend Yield': '1.16',
#   'Valorização': '-7.12'},
#  {'Papel': 'aflt3',
#   'Empresa': 'AFLUENTE TRANSMISSÃO DE ENERGIA ELÉTRICA S/A',
#   'CNPJ': '10.338.320/0001-00',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '271493000',
#   'Ativos': '314644000',
#   'Ativo circulante': '79408000',
#   'Dívida bruta': '389000',
#   'Disponibilidade': '31318000',
#   'Dívida líquida': '-30929000',
#   'Valor de mercado': '575963311',
#   'Valor de firma': '545034311',
#   'Número total de papéis': '63084700',
#   'Segmento de listagem': '',
#   'Free float': '1.37',
#   'Cotação atual': '9.13',
#   'Mínima 52 semanas': '8.14',
#   'Máxima 52 semanas': '10.50',
#   'Dividend Yield': '2.59',
#   'Valorização': '11.75'},
#  {'Papel': 'agro3',
#   'Empresa': 'BRASILAGRO - CIA BRAS DE PROP AGRICOLAS',
#   'CNPJ': '07.628.528/0001-59',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Agropecuária',
#   'Segmento de atuação': 'Agricultura',
#   'Patrimônio líquido': '2216048000',
#   'Ativos': '3345263000',
#   'Ativo circulante': '1588564000',
#   'Dívida bruta': '702192000',
#   'Disponibilidade': '530363000',
#   'Dívida líquida': '171829000',
#   'Valor de mercado': '2848128363',
#   'Valor de firma': '3019957363',
#   'Número total de papéis': '102377008',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '57.84',
#   'Cotação atual': '27.82',
#   'Mínima 52 semanas': '20.04',
#   'Máxima 52 semanas': '31.53',
#   'Dividend Yield': '18.89',
#   'Valorização': '17.04'},
#  {'Papel': 'agxy3',
#   'Empresa': 'AGROGALAXY PARTICIPAÇÕES S.A.',
#   'CNPJ': '21.240.146/0001-84',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Agropecuária',
#   'Segmento de atuação': 'Agricultura',
#   'Patrimônio líquido': '1255444000',
#   'Ativos': '7836693000',
#   'Ativo circulante': '6275065000',
#   'Dívida bruta': '1749238000',
#   'Disponibilidade': '436609000',
#   'Dívida líquida': '1312629000',
#   'Valor de mercado': '1655294143',
#   'Valor de firma': '2967923143',
#   'Número total de papéis': '170824989',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '37.88',
#   'Cotação atual': '9.69',
#   'Mínima 52 semanas': '6.66',
#   'Máxima 52 semanas': '12.00',
#   'Dividend Yield': '1.73',
#   'Valorização': '-6.83'},
#  {'Papel': 'aheb3',
#   'Empresa': 'SAO PAULO TURISMO S.A.',
#   'CNPJ': '62.002.886/0001-60',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Viagens e Lazer',
#   'Segmento de atuação': 'Produção de Eventos e Shows',
#   'Patrimônio líquido': '-80875000',
#   'Ativos': '290088000',
#   'Ativo circulante': '74583000',
#   'Dívida bruta': '4051000',
#   'Disponibilidade': '3242000',
#   'Dívida líquida': '809000',
#   'Valor de mercado': '170784028',
#   'Valor de firma': '171593028',
#   'Número total de papéis': '8543894',
#   'Segmento de listagem': '',
#   'Free float': '3.25',
#   'Cotação atual': '20.00',
#   'Mínima 52 semanas': '17.00',
#   'Máxima 52 semanas': '30.00',
#   'Dividend Yield': '-',
#   'Valorização': '-29.80'},
#  {'Papel': 'aheb5',
#   'Empresa': 'SAO PAULO TURISMO S.A.',
#   'CNPJ': '62.002.886/0001-60',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Viagens e Lazer',
#   'Segmento de atuação': 'Produção de Eventos e Shows',
#   'Patrimônio líquido': '-80875000',
#   'Ativos': '290088000',
#   'Ativo circulante': '74583000',
#   'Dívida bruta': '4051000',
#   'Disponibilidade': '3242000',
#   'Dívida líquida': '809000',
#   'Valor de mercado': '170784028',
#   'Valor de firma': '171593028',
#   'Número total de papéis': '8543894',
#   'Segmento de listagem': '',
#   'Free float': '3.25',
#   'Cotação atual': '22.00',
#   'Mínima 52 semanas': '-',
#   'Máxima 52 semanas': '-',
#   'Dividend Yield': '-',
#   'Valorização': '-'},
#  {'Papel': 'aheb6',
#   'Empresa': 'SAO PAULO TURISMO S.A.',
#   'CNPJ': '62.002.886/0001-60',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Viagens e Lazer',
#   'Segmento de atuação': 'Produção de Eventos e Shows',
#   'Patrimônio líquido': '-80875000',
#   'Ativos': '290088000',
#   'Ativo circulante': '74583000',
#   'Dívida bruta': '4051000',
#   'Disponibilidade': '3242000',
#   'Dívida líquida': '809000',
#   'Valor de mercado': '170784028',
#   'Valor de firma': '171593028',
#   'Número total de papéis': '8543894',
#   'Segmento de listagem': '',
#   'Free float': '3.25',
#   'Cotação atual': '19.31',
#   'Mínima 52 semanas': '19.31',
#   'Máxima 52 semanas': '41.20',
#   'Dividend Yield': '-',
#   'Valorização': '-53.13'},
#  {'Papel': 'alld3',
#   'Empresa': 'ALLIED TECNOLOGIA S.A.',
#   'CNPJ': '20.247.322/0001-47',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Eletrodomésticos',
#   'Patrimônio líquido': '1505197000',
#   'Ativos': '4194455000',
#   'Ativo circulante': '3003523000',
#   'Dívida bruta': '635666000',
#   'Disponibilidade': '303754000',
#   'Dívida líquida': '331912000',
#   'Valor de mercado': '555594669',
#   'Valor de firma': '887506669',
#   'Número total de papéis': '93220582',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '26.41',
#   'Cotação atual': '5.96',
#   'Mínima 52 semanas': '5.41',
#   'Máxima 52 semanas': '16.20',
#   'Dividend Yield': '15.52',
#   'Valorização': '-60.58'},
#  {'Papel': 'alpa3',
#   'Empresa': 'ALPARGATAS S.A.',
#   'CNPJ': '61.079.117/0001-05',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Tecidos. Vestuário e Calçados',
#   'Segmento de atuação': 'Calçados',
#   'Patrimônio líquido': '5860168000',
#   'Ativos': '7909699000',
#   'Ativo circulante': '3141501000',
#   'Dívida bruta': '381066000',
#   'Disponibilidade': '240984000',
#   'Dívida líquida': '140082000',
#   'Valor de mercado': '8652457152',
#   'Valor de firma': '8792539152',
#   'Número total de papéis': '683062222',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '31.69',
#   'Cotação atual': '11.45',
#   'Mínima 52 semanas': '10.89',
#   'Máxima 52 semanas': '28.97',
#   'Dividend Yield': '-',
#   'Valorização': '-60.48'},
#  {'Papel': 'alpa4',
#   'Empresa': 'ALPARGATAS S.A.',
#   'CNPJ': '61.079.117/0001-05',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Tecidos. Vestuário e Calçados',
#   'Segmento de atuação': 'Calçados',
#   'Patrimônio líquido': '5860168000',
#   'Ativos': '7909699000',
#   'Ativo circulante': '3141501000',
#   'Dívida bruta': '381066000',
#   'Disponibilidade': '240984000',
#   'Dívida líquida': '140082000',
#   'Valor de mercado': '8652457152',
#   'Valor de firma': '8792539152',
#   'Número total de papéis': '683062222',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '31.69',
#   'Cotação atual': '13.87',
#   'Mínima 52 semanas': '13.26',
#   'Máxima 52 semanas': '33.45',
#   'Dividend Yield': '-',
#   'Valorização': '-57.13'},
#  {'Papel': 'alpk3',
#   'Empresa': 'ALLPARK EMPREENDIMENTOS PARTICIPACOES SERVICOS S.A',
#   'CNPJ': '60.537.263/0001-66',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Serviços',
#   'Segmento de atuação': 'Serviços Diversos',
#   'Patrimônio líquido': '459504000',
#   'Ativos': '2607597000',
#   'Ativo circulante': '293216000',
#   'Dívida bruta': '1391462000',
#   'Disponibilidade': '118342000',
#   'Dívida líquida': '1273120000',
#   'Valor de mercado': '375246415',
#   'Valor de firma': '1648366415',
#   'Número total de papéis': '214426523',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '41.17',
#   'Cotação atual': '1.75',
#   'Mínima 52 semanas': '1.38',
#   'Máxima 52 semanas': '5.27',
#   'Dividend Yield': '-',
#   'Valorização': '-56.25'},
#  {'Papel': 'also3',
#   'Empresa': 'ALIANSCE SONAE SHOPPING CENTERS S.A.',
#   'CNPJ': '05.878.397/0001-32',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Exploração de Imóveis',
#   'Segmento de atuação': 'Exploração de Imóveis',
#   'Patrimônio líquido': '6924053000',
#   'Ativos': '12330073000',
#   'Ativo circulante': '3185608000',
#   'Dívida bruta': '0',
#   'Disponibilidade': '2633946000',
#   'Dívida líquida': '-2633946000',
#   'Valor de mercado': '4441063120',
#   'Valor de firma': '1807117120',
#   'Número total de papéis': '265772778',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '46.08',
#   'Cotação atual': '16.71',
#   'Mínima 52 semanas': '15.58',
#   'Máxima 52 semanas': '23.45',
#   'Dividend Yield': '2.30',
#   'Valorização': '-8.59'},
#  {'Papel': 'alup11',
#   'Empresa': 'ALUPAR INVESTIMENTO S/A',
#   'CNPJ': '08.364.948/0001-38',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '7282800000',
#   'Ativos': '27196461000',
#   'Ativo circulante': '4906614000',
#   'Dívida bruta': '10782022000',
#   'Disponibilidade': '2305417000',
#   'Dívida líquida': '8476605000',
#   'Valor de mercado': '7979399952',
#   'Valor de firma': '16456004952',
#   'Número total de papéis': '879111269',
#   'Segmento de listagem': 'Nível 2',
#   'Free float': '47.84',
#   'Cotação atual': '27.23',
#   'Mínima 52 semanas': '22.28',
#   'Máxima 52 semanas': '29.15',
#   'Dividend Yield': '4.52',
#   'Valorização': '20.97'},
#  {'Papel': 'alup3',
#   'Empresa': 'ALUPAR INVESTIMENTO S/A',
#   'CNPJ': '08.364.948/0001-38',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '7282800000',
#   'Ativos': '27196461000',
#   'Ativo circulante': '4906614000',
#   'Dívida bruta': '10782022000',
#   'Disponibilidade': '2305417000',
#   'Dívida líquida': '8476605000',
#   'Valor de mercado': '7979399952',
#   'Valor de firma': '16456004952',
#   'Número total de papéis': '879111269',
#   'Segmento de listagem': 'Nível 2',
#   'Free float': '47.84',
#   'Cotação atual': '9.06',
#   'Mínima 52 semanas': '7.43',
#   'Máxima 52 semanas': '10.30',
#   'Dividend Yield': '4.53',
#   'Valorização': '20.16'},
#  {'Papel': 'alup4',
#   'Empresa': 'ALUPAR INVESTIMENTO S/A',
#   'CNPJ': '08.364.948/0001-38',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '7282800000',
#   'Ativos': '27196461000',
#   'Ativo circulante': '4906614000',
#   'Dívida bruta': '10782022000',
#   'Disponibilidade': '2305417000',
#   'Dívida líquida': '8476605000',
#   'Valor de mercado': '7979399952',
#   'Valor de firma': '16456004952',
#   'Número total de papéis': '879111269',
#   'Segmento de listagem': 'Nível 2',
#   'Free float': '47.84',
#   'Cotação atual': '9.15',
#   'Mínima 52 semanas': '7.41',
#   'Máxima 52 semanas': '9.75',
#   'Dividend Yield': '4.48',
#   'Valorização': '21.35'},
#  {'Papel': 'amar3',
#   'Empresa': 'MARISA LOJAS S.A.',
#   'CNPJ': '61.189.288/0001-89',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Tecidos. Vestuário e Calçados',
#   'Patrimônio líquido': '973981000',
#   'Ativos': '3582988000',
#   'Ativo circulante': '1643516000',
#   'Dívida bruta': '1712555000',
#   'Disponibilidade': '183281000',
#   'Dívida líquida': '1529274000',
#   'Valor de mercado': '442267356',
#   'Valor de firma': '1971541356',
#   'Número total de papéis': '342842912',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '45.56',
#   'Cotação atual': '1.29',
#   'Mínima 52 semanas': '1.07',
#   'Máxima 52 semanas': '3.56',
#   'Dividend Yield': '-',
#   'Valorização': '-57.84'},
#  {'Papel': 'ambp3',
#   'Empresa': 'AMBIPAR PARTICIPACOES E EMPREENDIMENTOS S/A',
#   'CNPJ': '12.648.266/0001-24',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Água e Saneamento',
#   'Segmento de atuação': 'Água e Saneamento',
#   'Patrimônio líquido': '1033459000',
#   'Ativos': '8055197000',
#   'Ativo circulante': '3795169000',
#   'Dívida bruta': '5461170000',
#   'Disponibilidade': '2381428000',
#   'Dívida líquida': '3079742000',
#   'Valor de mercado': '2281298878',
#   'Valor de firma': '5361040878',
#   'Número total de papéis': '112935588',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '38.83',
#   'Cotação atual': '20.20',
#   'Mínima 52 semanas': '19.01',
#   'Máxima 52 semanas': '40.60',
#   'Dividend Yield': '1.50',
#   'Valorização': '-42.48'},
#  {'Papel': 'amer3',
#   'Empresa': 'AMERICANAS S.A',
#   'CNPJ': '00.776.574/0001-56',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Produtos Diversos',
#   'Patrimônio líquido': '15106033000',
#   'Ativos': '43364028000',
#   'Ativo circulante': '19325374000',
#   'Dívida bruta': '15522660000',
#   'Disponibilidade': '6567487000',
#   'Dívida líquida': '8955173000',
#   'Valor de mercado': '9395332126',
#   'Valor de firma': '18350505126',
#   'Número total de papéis': '902529503',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '67.78',
#   'Cotação atual': '10.41',
#   'Mínima 52 semanas': '7.35',
#   'Máxima 52 semanas': '35.86',
#   'Dividend Yield': '5.97',
#   'Valorização': '-61.59'},
#  {'Papel': 'anim3',
#   'Empresa': 'ANIMA HOLDING S.A.',
#   'CNPJ': '09.288.252/0001-32',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Diversos',
#   'Segmento de atuação': 'Serviços Educacionais',
#   'Patrimônio líquido': '2688957000',
#   'Ativos': '10477833000',
#   'Ativo circulante': '2117333000',
#   'Dívida bruta': '5064660000',
#   'Disponibilidade': '1214564000',
#   'Dívida líquida': '3850096000',
#   'Valor de mercado': '1449889010',
#   'Valor de firma': '5299985010',
#   'Número total de papéis': '403868805',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '63.58',
#   'Cotação atual': '3.59',
#   'Mínima 52 semanas': '3.57',
#   'Máxima 52 semanas': '8.83',
#   'Dividend Yield': '-',
#   'Valorização': '-49.44'},
#  {'Papel': 'aper3',
#   'Empresa': 'ALPER CONSULTORIA E CORRETORA DE SEGUROS S.A.',
#   'CNPJ': '11.721.921/0001-60',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Previdência e Seguros',
#   'Segmento de atuação': 'Corretoras de Seguros',
#   'Patrimônio líquido': '468023000',
#   'Ativos': '772422000',
#   'Ativo circulante': '223972000',
#   'Dívida bruta': '0',
#   'Disponibilidade': '137188000',
#   'Dívida líquida': '-137188000',
#   'Valor de mercado': '297335471',
#   'Valor de firma': '160147471',
#   'Número total de papéis': '11480134',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '133.98',
#   'Cotação atual': '25.90',
#   'Mínima 52 semanas': '23.67',
#   'Máxima 52 semanas': '39.21',
#   'Dividend Yield': '0.27',
#   'Valorização': '-10.47'},
#  {'Papel': 'apti4',
#   'Empresa': 'SIDERURGICA J. L. ALIPERTI S.A.',
#   'CNPJ': '61.156.931/0001-78',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Agropecuária',
#   'Segmento de atuação': 'Agricultura',
#   'Patrimônio líquido': '243433000',
#   'Ativos': '507673000',
#   'Ativo circulante': '209024000',
#   'Dívida bruta': '48121000',
#   'Disponibilidade': '69648000',
#   'Dívida líquida': '-21527000',
#   'Valor de mercado': '44442750',
#   'Valor de firma': '22915750',
#   'Número total de papéis': '18595',
#   'Segmento de listagem': '',
#   'Free float': '49.29',
#   'Cotação atual': '3500.00',
#   'Mínima 52 semanas': '-',
#   'Máxima 52 semanas': '-',
#   'Dividend Yield': '-',
#   'Valorização': '-'},
#  {'Papel': 'arml3',
#   'Empresa': 'ARMAC LOCAÇÃO. LOGÍSTICA E SERVIÇOS S.A.',
#   'CNPJ': '00.242.184/0001-04',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Máq. e Equip. Industriais',
#   'Patrimônio líquido': '1139267000',
#   'Ativos': '3468778000',
#   'Ativo circulante': '1192038000',
#   'Dívida bruta': '1886783000',
#   'Disponibilidade': '859354000',
#   'Dívida líquida': '1027429000',
#   'Valor de mercado': '3837317895',
#   'Valor de firma': '4864746895',
#   'Número total de papéis': '346016041',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '49.77',
#   'Cotação atual': '11.09',
#   'Mínima 52 semanas': '9.42',
#   'Máxima 52 semanas': '21.92',
#   'Dividend Yield': '3.67',
#   'Valorização': '-44.47'},
#  {'Papel': 'arzz3',
#   'Empresa': 'AREZZO INDÚSTRIA E COMÉRCIO S.A.',
#   'CNPJ': '16.590.234/0001-76',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Tecidos. Vestuário e Calçados',
#   'Patrimônio líquido': '2492432000',
#   'Ativos': '4194407000',
#   'Ativo circulante': '2192913000',
#   'Dívida bruta': '355287000',
#   'Disponibilidade': '715247000',
#   'Dívida líquida': '-359960000',
#   'Valor de mercado': '8352104637',
#   'Valor de firma': '7992144637',
#   'Número total de papéis': '110186077',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '55.14',
#   'Cotação atual': '75.80',
#   'Mínima 52 semanas': '63.40',
#   'Máxima 52 semanas': '103.60',
#   'Dividend Yield': '2.42',
#   'Valorização': '14.92'},
#  {'Papel': 'asai3',
#   'Empresa': 'SENDAS DISTRIBUIDORA S.A.',
#   'CNPJ': '06.057.223/0001-71',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Comércio e Distribuição',
#   'Segmento de atuação': 'Alimentos',
#   'Patrimônio líquido': '3595000000',
#   'Ativos': '36422000000',
#   'Ativo circulante': '12264000000',
#   'Dívida bruta': '12135000000',
#   'Disponibilidade': '4210000000',
#   'Dívida líquida': '7925000000',
#   'Valor de mercado': '25688109102',
#   'Valor de firma': '33613109102',
#   'Número total de papéis': '1349165394',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '69.36',
#   'Cotação atual': '19.04',
#   'Mínima 52 semanas': '11.19',
#   'Máxima 52 semanas': '20.51',
#   'Dividend Yield': '0.85',
#   'Valorização': '69.40'},
#  {'Papel': 'atmp3',
#   'Empresa': 'ATMA SA',
#   'CNPJ': '04.032.433/0001-80',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Serviços',
#   'Segmento de atuação': 'Serviços Diversos',
#   'Patrimônio líquido': '-275079000',
#   'Ativos': '1603281000',
#   'Ativo circulante': '429439000',
#   'Dívida bruta': '364129000',
#   'Disponibilidade': '96955000',
#   'Dívida líquida': '267174000',
#   'Valor de mercado': '32052427',
#   'Valor de firma': '299226427',
#   'Número total de papéis': '26710356',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '28.69',
#   'Cotação atual': '1.20',
#   'Mínima 52 semanas': '1.01',
#   'Máxima 52 semanas': '3.20',
#   'Dividend Yield': '-',
#   'Valorização': '-52.00'},
#  {'Papel': 'atom3',
#   'Empresa': 'ATOM EMPREENDIMENTOS E PARTICIPAÇÕES S.A.',
#   'CNPJ': '00.359.742/0001-08',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Outros',
#   'Segmento de atuação': 'Outros',
#   'Patrimônio líquido': '25629000',
#   'Ativos': '35889000',
#   'Ativo circulante': '35113000',
#   'Dívida bruta': '0',
#   'Disponibilidade': '20638000',
#   'Dívida líquida': '-20638000',
#   'Valor de mercado': '57131755',
#   'Valor de firma': '36493755',
#   'Número total de papéis': '23804898',
#   'Segmento de listagem': '',
#   'Free float': '25.34',
#   'Cotação atual': '2.40',
#   'Mínima 52 semanas': '2.05',
#   'Máxima 52 semanas': '3.62',
#   'Dividend Yield': '2.87',
#   'Valorização': '-27.27'},
#  {'Papel': 'aure3',
#   'Empresa': 'AUREN ENERGIA S.A.',
#   'CNPJ': '28.594.234/0001-23',
#   'Setor de atuação': 'Utilidade Pública',
#   'Subsetor de atuação': 'Energia Elétrica',
#   'Segmento de atuação': 'Energia Elétrica',
#   'Patrimônio líquido': '12732202000',
#   'Ativos': '29391370000',
#   'Ativo circulante': '5950290000',
#   'Dívida bruta': '5591229000',
#   'Disponibilidade': '3353966000',
#   'Dívida líquida': '2237263000',
#   'Valor de mercado': '14580000000',
#   'Valor de firma': '16817263000',
#   'Número total de papéis': '1000000000',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '30.20',
#   'Cotação atual': '14.58',
#   'Mínima 52 semanas': '12.79',
#   'Máxima 52 semanas': '16.60',
#   'Dividend Yield': '0.69',
#   'Valorização': '-11.10'},
#  {'Papel': 'avll3',
#   'Empresa': 'ALPHAVILLE S.A.',
#   'CNPJ': '16.811.931/0001-00',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Construção Civil',
#   'Segmento de atuação': 'Incorporações',
#   'Patrimônio líquido': '-183581000',
#   'Ativos': '1755384000',
#   'Ativo circulante': '631943000',
#   'Dívida bruta': '959203000',
#   'Disponibilidade': '97842000',
#   'Dívida líquida': '861361000',
#   'Valor de mercado': '156910558',
#   'Valor de firma': '1018271558',
#   'Número total de papéis': '22415794',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '19.88',
#   'Cotação atual': '7.00',
#   'Mínima 52 semanas': '5.18',
#   'Máxima 52 semanas': '32.87',
#   'Dividend Yield': '-',
#   'Valorização': '-75.60'},
#  {'Papel': 'azev3',
#   'Empresa': 'AZEVEDO E TRAVASSOS S.A.',
#   'CNPJ': '61.351.532/0001-68',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Construção e Engenharia',
#   'Segmento de atuação': 'Construção Pesada',
#   'Patrimônio líquido': '124647000',
#   'Ativos': '495858000',
#   'Ativo circulante': '161260000',
#   'Dívida bruta': '46778000',
#   'Disponibilidade': '15994000',
#   'Dívida líquida': '30784000',
#   'Valor de mercado': '127155536',
#   'Valor de firma': '157939536',
#   'Número total de papéis': '77180469',
#   'Segmento de listagem': '',
#   'Free float': '70.52',
#   'Cotação atual': '1.70',
#   'Mínima 52 semanas': '1.31',
#   'Máxima 52 semanas': '4.01',
#   'Dividend Yield': '-',
#   'Valorização': '-55.03'},
#  {'Papel': 'azev4',
#   'Empresa': 'AZEVEDO E TRAVASSOS S.A.',
#   'CNPJ': '61.351.532/0001-68',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Construção e Engenharia',
#   'Segmento de atuação': 'Construção Pesada',
#   'Patrimônio líquido': '124647000',
#   'Ativos': '495858000',
#   'Ativo circulante': '161260000',
#   'Dívida bruta': '46778000',
#   'Disponibilidade': '15994000',
#   'Dívida líquida': '30784000',
#   'Valor de mercado': '127155536',
#   'Valor de firma': '157939536',
#   'Número total de papéis': '77180469',
#   'Segmento de listagem': '',
#   'Free float': '70.52',
#   'Cotação atual': '1.62',
#   'Mínima 52 semanas': '1.21',
#   'Máxima 52 semanas': '2.84',
#   'Dividend Yield': '-',
#   'Valorização': '-23.22'},
#  {'Papel': 'azul4',
#   'Empresa': 'AZUL S.A.',
#   'CNPJ': '09.305.994/0001-29',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Transporte',
#   'Segmento de atuação': 'Transporte Aéreo',
#   'Patrimônio líquido': '-20130507000',
#   'Ativos': '18318914000',
#   'Ativo circulante': '5129421000',
#   'Dívida bruta': '23874188000',
#   'Disponibilidade': '1103991000',
#   'Dívida líquida': '22770197000',
#   'Valor de mercado': '4120368648',
#   'Valor de firma': '26890565648',
#   'Número total de papéis': '1264582966',
#   'Segmento de listagem': 'Nível 2',
#   'Free float': '50.15',
#   'Cotação atual': '11.84',
#   'Mínima 52 semanas': '9.44',
#   'Máxima 52 semanas': '29.29',
#   'Dividend Yield': '-',
#   'Valorização': '-50.46'},
#  {'Papel': 'b3sa3',
#   'Empresa': 'B3 S.A. - BRASIL, BOLSA, BALCÃO',
#   'CNPJ': '09.346.601/0001-25',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Serviços Financeiros Diversos',
#   'Segmento de atuação': 'Serviços Financeiros Diversos',
#   'Patrimônio líquido': '20417543000',
#   'Ativos': '48771393000',
#   'Ativo circulante': '18498360000',
#   'Dívida bruta': '12300701000',
#   'Disponibilidade': '16748752000',
#   'Dívida líquida': '-4448051000',
#   'Valor de mercado': '76786410000',
#   'Valor de firma': '72338359000',
#   'Número total de papéis': '6099000000',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '96.77',
#   'Cotação atual': '12.59',
#   'Mínima 52 semanas': '9.95',
#   'Máxima 52 semanas': '15.82',
#   'Dividend Yield': '3.84',
#   'Valorização': '14.35'},
#  {'Papel': 'bahi3',
#   'Empresa': 'BAHEMA S.A.',
#   'CNPJ': '45.987.245/0001-92',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Diversos',
#   'Segmento de atuação': 'Serviços Educacionais',
#   'Patrimônio líquido': '133675000',
#   'Ativos': '638239000',
#   'Ativo circulante': '35382000',
#   'Dívida bruta': '125904000',
#   'Disponibilidade': '3563000',
#   'Dívida líquida': '122341000',
#   'Valor de mercado': '259529283',
#   'Valor de firma': '381870283',
#   'Número total de papéis': '23897724',
#   'Segmento de listagem': '',
#   'Free float': '28.82',
#   'Cotação atual': '10.86',
#   'Mínima 52 semanas': '9.11',
#   'Máxima 52 semanas': '16.69',
#   'Dividend Yield': '-',
#   'Valorização': '-25.05'},
#  {'Papel': 'balm3',
#   'Empresa': 'BAUMER S.A.',
#   'CNPJ': '61.374.161/0001-30',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Equipamentos',
#   'Segmento de atuação': 'Equipamentos',
#   'Patrimônio líquido': '136239000',
#   'Ativos': '226905000',
#   'Ativo circulante': '155315000',
#   'Dívida bruta': '19574000',
#   'Disponibilidade': '38641000',
#   'Dívida líquida': '-19067000',
#   'Valor de mercado': '105154000',
#   'Valor de firma': '86087000',
#   'Número total de papéis': '9800000',
#   'Segmento de listagem': '',
#   'Free float': '34.88',
#   'Cotação atual': '11.51',
#   'Mínima 52 semanas': '10.01',
#   'Máxima 52 semanas': '16.99',
#   'Dividend Yield': '3.10',
#   'Valorização': '-25.74'},
#  {'Papel': 'balm4',
#   'Empresa': 'BAUMER S.A.',
#   'CNPJ': '61.374.161/0001-30',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Equipamentos',
#   'Segmento de atuação': 'Equipamentos',
#   'Patrimônio líquido': '136239000',
#   'Ativos': '226905000',
#   'Ativo circulante': '155315000',
#   'Dívida bruta': '19574000',
#   'Disponibilidade': '38641000',
#   'Dívida líquida': '-19067000',
#   'Valor de mercado': '105154000',
#   'Valor de firma': '86087000',
#   'Número total de papéis': '9800000',
#   'Segmento de listagem': '',
#   'Free float': '34.88',
#   'Cotação atual': '9.95',
#   'Mínima 52 semanas': '9.40',
#   'Máxima 52 semanas': '13.00',
#   'Dividend Yield': '3.59',
#   'Valorização': '-20.27'},
#  {'Papel': 'bauh4',
#   'Empresa': 'EXCELSIOR ALIMENTOS S.A.',
#   'CNPJ': '95.426.862/0001-97',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Alimentos Processados',
#   'Segmento de atuação': 'Carnes e Derivados',
#   'Patrimônio líquido': '107672000',
#   'Ativos': '165489000',
#   'Ativo circulante': '51666000',
#   'Dívida bruta': '15361000',
#   'Disponibilidade': '15458000',
#   'Dívida líquida': '-97000',
#   'Valor de mercado': '438092204',
#   'Valor de firma': '437995204',
#   'Número total de papéis': '5222222',
#   'Segmento de listagem': '',
#   'Free float': '28.89',
#   'Cotação atual': '83.89',
#   'Mínima 52 semanas': '70.50',
#   'Máxima 52 semanas': '85.90',
#   'Dividend Yield': '-',
#   'Valorização': '-0.01'},
#  {'Papel': 'baza3',
#   'Empresa': 'BCO AMAZONIA S.A.',
#   'CNPJ': '04.902.979/0001-44',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '4470162000',
#   'Ativos': '32685445000',
#   'Ativo circulante': '3095430000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '3095430000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '2707616615',
#   'Valor de firma': '2707616615',
#   'Número total de papéis': '56058315',
#   'Segmento de listagem': '',
#   'Free float': '2.99',
#   'Cotação atual': '48.30',
#   'Mínima 52 semanas': '37.30',
#   'Máxima 52 semanas': '54.00',
#   'Dividend Yield': '14.22',
#   'Valorização': '23.75'},
#  {'Papel': 'bbas3',
#   'Empresa': 'BCO BRASIL S.A.',
#   'CNPJ': '00.000.000/0001-91',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '153122204000',
#   'Ativos': '2096035145000',
#   'Ativo circulante': '50197059000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '50197059000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '100432866551',
#   'Valor de firma': '100432866551',
#   'Número total de papéis': '2865417020',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '49.58',
#   'Cotação atual': '35.05',
#   'Mínima 52 semanas': '26.44',
#   'Máxima 52 semanas': '43.39',
#   'Dividend Yield': '11.90',
#   'Valorização': '32.56'},
#  {'Papel': 'bbdc3',
#   'Empresa': 'BCO BRADESCO S.A.',
#   'CNPJ': '60.746.948/0001-12',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '161359321000',
#   'Ativos': '1861372023000',
#   'Ativo circulante': '148531503000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '148531503000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '151761863737',
#   'Valor de firma': '151761863737',
#   'Número total de papéis': '10658488028',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '62.53',
#   'Cotação atual': '13.42',
#   'Mínima 52 semanas': '12.18',
#   'Máxima 52 semanas': '17.48',
#   'Dividend Yield': '6.83',
#   'Valorização': '-9.75'},
#  {'Papel': 'bbdc4',
#   'Empresa': 'BCO BRADESCO S.A.',
#   'CNPJ': '60.746.948/0001-12',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '161359321000',
#   'Ativos': '1861372023000',
#   'Ativo circulante': '148531503000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '148531503000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '151761863737',
#   'Valor de firma': '151761863737',
#   'Número total de papéis': '10658488028',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '62.53',
#   'Cotação atual': '15.06',
#   'Mínima 52 semanas': '13.70',
#   'Máxima 52 semanas': '21.33',
#   'Dividend Yield': '6.69',
#   'Valorização': '-16.47'},
#  {'Papel': 'bbse3',
#   'Empresa': 'BB SEGURIDADE PARTICIPAÇÕES S.A.',
#   'CNPJ': '17.344.597/0001-94',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Previdência e Seguros',
#   'Segmento de atuação': 'Seguradoras',
#   'Patrimônio líquido': '9460891000',
#   'Ativos': '13930986000',
#   'Ativo circulante': '5636115000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '4664850000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '67060000000',
#   'Valor de firma': '67060000000',
#   'Número total de papéis': '2000000000',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '33.58',
#   'Cotação atual': '33.53',
#   'Mínima 52 semanas': '17.79',
#   'Máxima 52 semanas': '33.99',
#   'Dividend Yield': '5.86',
#   'Valorização': '82.43'},
#  {'Papel': 'bdll3',
#   'Empresa': 'BARDELLA S.A. INDUSTRIAS MECANICAS',
#   'CNPJ': '60.851.615/0001-53',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Máq. e Equip. Industriais',
#   'Patrimônio líquido': '-197559000',
#   'Ativos': '690917000',
#   'Ativo circulante': '296517000',
#   'Dívida bruta': '219285000',
#   'Disponibilidade': '48318000',
#   'Dívida líquida': '170967000',
#   'Valor de mercado': '16221576',
#   'Valor de firma': '187188576',
#   'Número total de papéis': '1600000',
#   'Segmento de listagem': '',
#   'Free float': '76.88',
#   'Cotação atual': '12.00',
#   'Mínima 52 semanas': '9.90',
#   'Máxima 52 semanas': '13.19',
#   'Dividend Yield': '-',
#   'Valorização': '1.78'},
#  {'Papel': 'bdll4',
#   'Empresa': 'BARDELLA S.A. INDUSTRIAS MECANICAS',
#   'CNPJ': '60.851.615/0001-53',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Máq. e Equip. Industriais',
#   'Patrimônio líquido': '-197559000',
#   'Ativos': '690917000',
#   'Ativo circulante': '296517000',
#   'Dívida bruta': '219285000',
#   'Disponibilidade': '48318000',
#   'Dívida líquida': '170967000',
#   'Valor de mercado': '16221576',
#   'Valor de firma': '187188576',
#   'Número total de papéis': '1600000',
#   'Segmento de listagem': '',
#   'Free float': '76.88',
#   'Cotação atual': '9.00',
#   'Mínima 52 semanas': '7.55',
#   'Máxima 52 semanas': '10.75',
#   'Dividend Yield': '-',
#   'Valorização': '-16.28'},
#  {'Papel': 'beef3',
#   'Empresa': 'MINERVA S.A.',
#   'CNPJ': '67.620.377/0001-14',
#   'Setor de atuação': 'Consumo não Cíclico',
#   'Subsetor de atuação': 'Alimentos Processados',
#   'Segmento de atuação': 'Carnes e Derivados',
#   'Patrimônio líquido': '621997000',
#   'Ativos': '21332804000',
#   'Ativo circulante': '14474464000',
#   'Dívida bruta': '14444149000',
#   'Disponibilidade': '7966149000',
#   'Dívida líquida': '6478000000',
#   'Valor de mercado': '8058650811',
#   'Valor de firma': '14536650811',
#   'Número total de papéis': '607283407',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '42.87',
#   'Cotação atual': '13.27',
#   'Mínima 52 semanas': '8.44',
#   'Máxima 52 semanas': '16.06',
#   'Dividend Yield': '4.23',
#   'Valorização': '39.54'},
#  {'Papel': 'bees3',
#   'Empresa': 'BANESTES S.A. - BCO EST ESPIRITO SANTO',
#   'CNPJ': '28.127.603/0001-78',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '1951430000',
#   'Ativos': '39014276000',
#   'Ativo circulante': '6280110000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '6280110000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '1850859747',
#   'Valor de firma': '1850859747',
#   'Número total de papéis': '315912860',
#   'Segmento de listagem': '',
#   'Free float': '4.61',
#   'Cotação atual': '5.59',
#   'Mínima 52 semanas': '4.42',
#   'Máxima 52 semanas': '5.96',
#   'Dividend Yield': '10.49',
#   'Valorização': '26.47'},
#  {'Papel': 'bees4',
#   'Empresa': 'BANESTES S.A. - BCO EST ESPIRITO SANTO',
#   'CNPJ': '28.127.603/0001-78',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '1951430000',
#   'Ativos': '39014276000',
#   'Ativo circulante': '6280110000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '6280110000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '1850859747',
#   'Valor de firma': '1850859747',
#   'Número total de papéis': '315912860',
#   'Segmento de listagem': '',
#   'Free float': '4.61',
#   'Cotação atual': '6.59',
#   'Mínima 52 semanas': '4.67',
#   'Máxima 52 semanas': '6.59',
#   'Dividend Yield': '8.90',
#   'Valorização': '23.18'},
#  {'Papel': 'bgip3',
#   'Empresa': 'BCO ESTADO DE SERGIPE S.A. - BANESE',
#   'CNPJ': '13.009.717/0001-46',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '582335000',
#   'Ativos': '8055549000',
#   'Ativo circulante': '4389913000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '1821272000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '331304326',
#   'Valor de firma': '331304326',
#   'Número total de papéis': '15285090',
#   'Segmento de listagem': '',
#   'Free float': '10.13',
#   'Cotação atual': '26.40',
#   'Mínima 52 semanas': '26.40',
#   'Máxima 52 semanas': '34.78',
#   'Dividend Yield': '3.78',
#   'Valorização': '-24.09'},
#  {'Papel': 'bgip4',
#   'Empresa': 'BCO ESTADO DE SERGIPE S.A. - BANESE',
#   'CNPJ': '13.009.717/0001-46',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '582335000',
#   'Ativos': '8055549000',
#   'Ativo circulante': '4389913000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '1821272000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '331304326',
#   'Valor de firma': '331304326',
#   'Número total de papéis': '15285090',
#   'Segmento de listagem': '',
#   'Free float': '10.13',
#   'Cotação atual': '16.95',
#   'Mínima 52 semanas': '16.95',
#   'Máxima 52 semanas': '25.96',
#   'Dividend Yield': '6.47',
#   'Valorização': '-28.24'},
#  {'Papel': 'bidi11',
#   'Empresa': 'BANCO INTER S.A.',
#   'CNPJ': '00.416.968/0001-01',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '8357164000',
#   'Ativos': '38625095000',
#   'Ativo circulante': '1171640000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '0',
#   'Dívida líquida': '-',
#   'Valor de mercado': '8991139765',
#   'Valor de firma': '8991139765',
#   'Número total de papéis': '2593598009',
#   'Segmento de listagem': '',
#   'Free float': '67.54',
#   'Cotação atual': '10.40',
#   'Mínima 52 semanas': '9.65',
#   'Máxima 52 semanas': '28.20',
#   'Dividend Yield': '0.43',
#   'Valorização': '-61.00'},
#  {'Papel': 'bidi3',
#   'Empresa': 'BANCO INTER S.A.',
#   'CNPJ': '00.416.968/0001-01',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '8357164000',
#   'Ativos': '38625095000',
#   'Ativo circulante': '1171640000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '0',
#   'Dívida líquida': '-',
#   'Valor de mercado': '8991139765',
#   'Valor de firma': '8991139765',
#   'Número total de papéis': '2593598009',
#   'Segmento de listagem': '',
#   'Free float': '67.54',
#   'Cotação atual': '3.40',
#   'Mínima 52 semanas': '3.20',
#   'Máxima 52 semanas': '9.42',
#   'Dividend Yield': '0.43',
#   'Valorização': '-61.97'},
#  {'Papel': 'bidi4',
#   'Empresa': 'BANCO INTER S.A.',
#   'CNPJ': '00.416.968/0001-01',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '8357164000',
#   'Ativos': '38625095000',
#   'Ativo circulante': '1171640000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '0',
#   'Dívida líquida': '-',
#   'Valor de mercado': '8991139765',
#   'Valor de firma': '8991139765',
#   'Número total de papéis': '2593598009',
#   'Segmento de listagem': '',
#   'Free float': '67.54',
#   'Cotação atual': '3.41',
#   'Mínima 52 semanas': '3.22',
#   'Máxima 52 semanas': '9.35',
#   'Dividend Yield': '0.43',
#   'Valorização': '-61.12'},
#  {'Papel': 'biom3',
#   'Empresa': 'BIOMM S.A.',
#   'CNPJ': '04.752.991/0001-10',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Comércio e Distribuição',
#   'Segmento de atuação': 'Medicamentos e Outros Produtos',
#   'Patrimônio líquido': '146482000',
#   'Ativos': '381976000',
#   'Ativo circulante': '158514000',
#   'Dívida bruta': '172425000',
#   'Disponibilidade': '80945000',
#   'Dívida líquida': '91480000',
#   'Valor de mercado': '516177682',
#   'Valor de firma': '607657682',
#   'Número total de papéis': '81287824',
#   'Segmento de listagem': '',
#   'Free float': '40.93',
#   'Cotação atual': '6.35',
#   'Mínima 52 semanas': '5.40',
#   'Máxima 52 semanas': '14.33',
#   'Dividend Yield': '-',
#   'Valorização': '-52.22'},
#  {'Papel': 'bkbr3',
#   'Empresa': 'ZAMP S.A.',
#   'CNPJ': '13.574.594/0001-96',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Hoteis e Restaurantes',
#   'Segmento de atuação': 'Restaurante e Similares',
#   'Patrimônio líquido': '1456994000',
#   'Ativos': '3994258000',
#   'Ativo circulante': '998190000',
#   'Dívida bruta': '1077977000',
#   'Disponibilidade': '548661000',
#   'Dívida líquida': '529316000',
#   'Valor de mercado': '1445616097',
#   'Valor de firma': '1974932097',
#   'Número total de papéis': '275355447',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '98.27',
#   'Cotação atual': '7.63',
#   'Mínima 52 semanas': '5.18',
#   'Máxima 52 semanas': '8.80',
#   'Dividend Yield': '-',
#   'Valorização': '2.69'},
#  {'Papel': 'blau3',
#   'Empresa': 'BLAU FARMACÊUTICA S.A.',
#   'CNPJ': '58.430.828/0001-60',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Medicamentos e Outros Produtos',
#   'Segmento de atuação': 'Medicamentos e Outros Produtos',
#   'Patrimônio líquido': '1759860000',
#   'Ativos': '2440588000',
#   'Ativo circulante': '1713234000',
#   'Dívida bruta': '316155000',
#   'Disponibilidade': '763533000',
#   'Dívida líquida': '-447378000',
#   'Valor de mercado': '4698327262',
#   'Valor de firma': '4250949262',
#   'Número total de papéis': '179393939',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '16.63',
#   'Cotação atual': '26.19',
#   'Mínima 52 semanas': '21.62',
#   'Máxima 52 semanas': '36.58',
#   'Dividend Yield': '3.24',
#   'Valorização': '-15.41'},
#  {'Papel': 'blut3',
#   'Empresa': 'BLUE TECH SOLUTIONS E.Q.I. S',
#   'CNPJ': '60.637.238/0001-54',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Holdings Diversificadas',
#   'Segmento de atuação': 'Holdings Diversificadas',
#   'Patrimônio líquido': '57197000',
#   'Ativos': '189813000',
#   'Ativo circulante': '67000',
#   'Dívida bruta': '6748000',
#   'Disponibilidade': '1000',
#   'Dívida líquida': '6747000',
#   'Valor de mercado': '14115600',
#   'Valor de firma': '20862600',
#   'Número total de papéis': '5102814',
#   'Segmento de listagem': '',
#   'Free float': '393.44',
#   'Cotação atual': '5.14',
#   'Mínima 52 semanas': '3.72',
#   'Máxima 52 semanas': '7.08',
#   'Dividend Yield': '-',
#   'Valorização': '-1.15'},
#  {'Papel': 'blut4',
#   'Empresa': 'BLUE TECH SOLUTIONS E.Q.I. S',
#   'CNPJ': '60.637.238/0001-54',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Holdings Diversificadas',
#   'Segmento de atuação': 'Holdings Diversificadas',
#   'Patrimônio líquido': '57197000',
#   'Ativos': '189813000',
#   'Ativo circulante': '67000',
#   'Dívida bruta': '6748000',
#   'Disponibilidade': '1000',
#   'Dívida líquida': '6747000',
#   'Valor de mercado': '14115600',
#   'Valor de firma': '20862600',
#   'Número total de papéis': '5102814',
#   'Segmento de listagem': '',
#   'Free float': '393.44',
#   'Cotação atual': '1.52',
#   'Mínima 52 semanas': '1.52',
#   'Máxima 52 semanas': '4.00',
#   'Dividend Yield': '-',
#   'Valorização': '-30.91'},
#  {'Papel': 'bmeb3',
#   'Empresa': 'BCO MERCANTIL DO BRASIL S.A.',
#   'CNPJ': '17.184.037/0001-10',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '1283674000',
#   'Ativos': '14964569000',
#   'Ativo circulante': '1948125000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '1948125000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '1076842368',
#   'Valor de firma': '1076842368',
#   'Número total de papéis': '104831580',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '47.01',
#   'Cotação atual': '10.45',
#   'Mínima 52 semanas': '9.63',
#   'Máxima 52 semanas': '18.01',
#   'Dividend Yield': '4.99',
#   'Valorização': '-8.73'},
#  {'Papel': 'bmeb4',
#   'Empresa': 'BCO MERCANTIL DO BRASIL S.A.',
#   'CNPJ': '17.184.037/0001-10',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '1283674000',
#   'Ativos': '14964569000',
#   'Ativo circulante': '1948125000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '1948125000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '1076842368',
#   'Valor de firma': '1076842368',
#   'Número total de papéis': '104831580',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '47.01',
#   'Cotação atual': '9.98',
#   'Mínima 52 semanas': '9.64',
#   'Máxima 52 semanas': '11.36',
#   'Dividend Yield': '5.74',
#   'Valorização': '-3.85'},
#  {'Papel': 'bmgb4',
#   'Empresa': 'BANCO BMG S.A.',
#   'CNPJ': '61.186.680/0001-74',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '4072017000',
#   'Ativos': '40719133000',
#   'Ativo circulante': '584440000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '300446000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '1294775952',
#   'Valor de firma': '1294775952',
#   'Número total de papéis': '583232411',
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '17.60',
#   'Cotação atual': '2.22',
#   'Mínima 52 semanas': '1.98',
#   'Máxima 52 semanas': '3.11',
#   'Dividend Yield': '16.46',
#   'Valorização': '-22.92'},
#  {'Papel': 'bmin3',
#   'Empresa': 'BCO MERCANTIL DE INVESTIMENTOS S.A.',
#   'CNPJ': '34.169.557/0001-72',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '132406000',
#   'Ativos': '298093000',
#   'Ativo circulante': '2907000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '2907000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '85552152',
#   'Valor de firma': '85552152',
#   'Número total de papéis': '4825200',
#   'Segmento de listagem': '',
#   'Free float': '8.47',
#   'Cotação atual': '18.50',
#   'Mínima 52 semanas': '18.50',
#   'Máxima 52 semanas': '23.00',
#   'Dividend Yield': '-',
#   'Valorização': '-15.14'},
#  {'Papel': 'bmin4',
#   'Empresa': 'BCO MERCANTIL DE INVESTIMENTOS S.A.',
#   'CNPJ': '34.169.557/0001-72',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Intermediários Financeiros',
#   'Segmento de atuação': 'Bancos',
#   'Patrimônio líquido': '132406000',
#   'Ativos': '298093000',
#   'Ativo circulante': '2907000',
#   'Dívida bruta': '-',
#   'Disponibilidade': '2907000',
#   'Dívida líquida': '-',
#   'Valor de mercado': '85552152',
#   'Valor de firma': '85552152',
#   'Número total de papéis': '4825200',
#   'Segmento de listagem': '',
#   'Free float': '8.47',
#   'Cotação atual': '13.27',
#   'Mínima 52 semanas': '12.25',
#   'Máxima 52 semanas': '18.34',
#   'Dividend Yield': '6.41',
#   'Valorização': '-20.25'},
#  {'Papel': 'bmks3',
# ...
#   'Segmento de listagem': 'Nível 1',
#   'Free float': '53.96',
#   'Cotação atual': '13.48',
#   'Mínima 52 semanas': '13.48',
#   'Máxima 52 semanas': '20.25',
#   'Dividend Yield': '4.67',
#   'Valorização': '-26.06'},
#  {'Papel': 'vale3',
#   'Empresa': 'VALE S.A.',
#   'CNPJ': '33.592.510/0001-54',
#   'Setor de atuação': 'Materiais Básicos',
#   'Subsetor de atuação': 'Mineração',
#   'Segmento de atuação': 'Minerais Metálicos',
#   'Patrimônio líquido': '179538000000',
#   'Ativos': '435833000000',
#   'Ativo circulante': '75270000000',
#   'Dívida bruta': '65977000000',
#   'Disponibilidade': '28240000000',
#   'Dívida líquida': '37737000000',
#   'Valor de mercado': '441282634545',
#   'Valor de firma': '479019634545',
#   'Número total de papéis': '4778889263',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '95.15',
#   'Cotação atual': '92.34',
#   'Mínima 52 semanas': '62.74',
#   'Máxima 52 semanas': '96.22',
#   'Dividend Yield': '8.21',
#   'Valorização': '20.03'},
#  {'Papel': 'vamo3',
#   'Empresa': 'VAMOS LOCAÇÃO DE CAMINHÕES. MÁQUINAS E EQUIP. S.A.',
#   'CNPJ': '23.373.000/0001-32',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Máq. e Equip. Construção e Agrícolas',
#   'Patrimônio líquido': '3655761000',
#   'Ativos': '15332220000',
#   'Ativo circulante': '5204545000',
#   'Dívida bruta': '7445040000',
#   'Disponibilidade': '3136511000',
#   'Dívida líquida': '4308529000',
#   'Valor de mercado': '12232997782',
#   'Valor de firma': '16541526782',
#   'Número total de papéis': '1025397970',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '30.69',
#   'Cotação atual': '11.93',
#   'Mínima 52 semanas': '9.74',
#   'Máxima 52 semanas': '16.36',
#   'Dividend Yield': '2.19',
#   'Valorização': '16.96'},
#  {'Papel': 'vbbr3',
#   'Empresa': 'VIBRA ENERGIA S.A.',
#   'CNPJ': '34.274.233/0001-02',
#   'Setor de atuação': 'Petróleo. Gás e Biocombustíveis',
#   'Subsetor de atuação': 'Petróleo. Gás e Biocombustíveis',
#   'Segmento de atuação': 'Exploração. Refino e Distribuição',
#   'Patrimônio líquido': '12636000000',
#   'Ativos': '39525000000',
#   'Ativo circulante': '20444000000',
#   'Dívida bruta': '16117000000',
#   'Disponibilidade': '3113000000',
#   'Dívida líquida': '13004000000',
#   'Valor de mercado': '17300250000',
#   'Valor de firma': '30304250000',
#   'Número total de papéis': '1165000000',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '95.66',
#   'Cotação atual': '14.85',
#   'Mínima 52 semanas': '13.94',
#   'Máxima 52 semanas': '23.49',
#   'Dividend Yield': '5.77',
#   'Valorização': '-19.07'},
#  {'Papel': 'viia3',
#   'Empresa': 'VIA S.A',
#   'CNPJ': '33.041.260/0652-90',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Eletrodomésticos',
#   'Patrimônio líquido': '5505000000',
#   'Ativos': '34041000000',
#   'Ativo circulante': '15217000000',
#   'Dívida bruta': '9316000000',
#   'Disponibilidade': '1232000000',
#   'Dívida líquida': '8084000000',
#   'Valor de mercado': '3852219406',
#   'Valor de firma': '11936219406',
#   'Número total de papéis': '1598431289',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '98.66',
#   'Cotação atual': '2.41',
#   'Mínima 52 semanas': '1.83',
#   'Máxima 52 semanas': '4.72',
#   'Dividend Yield': '-',
#   'Valorização': '-42.21'},
#  {'Papel': 'vitt3',
#   'Empresa': 'VITTIA FERTILIZANTES E BIOLOGICOS S.A.',
#   'CNPJ': '45.365.558/0001-09',
#   'Setor de atuação': 'Materiais Básicos',
#   'Subsetor de atuação': 'Químicos',
#   'Segmento de atuação': 'Fertilizantes e Defensivos',
#   'Patrimônio líquido': '483107000',
#   'Ativos': '880516000',
#   'Ativo circulante': '579865000',
#   'Dívida bruta': '278396000',
#   'Disponibilidade': '70050000',
#   'Dívida líquida': '208346000',
#   'Valor de mercado': '1673674552',
#   'Valor de firma': '1882020552',
#   'Número total de papéis': '143049107',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '35.34',
#   'Cotação atual': '11.70',
#   'Mínima 52 semanas': '8.70',
#   'Máxima 52 semanas': '15.39',
#   'Dividend Yield': '3.12',
#   'Valorização': '-1.10'},
#  {'Papel': 'viva3',
#   'Empresa': 'VIVARA PARTICIPAÇOES S.A',
#   'CNPJ': '33.839.910/0001-11',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Tecidos. Vestuário e Calçados',
#   'Segmento de atuação': 'Acessórios',
#   'Patrimônio líquido': '1392731364',
#   'Ativos': '2563868834',
#   'Ativo circulante': '1583219784',
#   'Dívida bruta': '291212771',
#   'Disponibilidade': '467294728',
#   'Dívida líquida': '-176081957',
#   'Valor de mercado': '4971963037',
#   'Valor de firma': '4795881080',
#   'Número total de papéis': '236197769',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '42.01',
#   'Cotação atual': '21.05',
#   'Mínima 52 semanas': '19.35',
#   'Máxima 52 semanas': '28.74',
#   'Dividend Yield': '0.26',
#   'Valorização': '-4.75'},
#  {'Papel': 'vivr3',
#   'Empresa': 'VIVER INCORPORADORA E CONSTRUTORA S.A.',
#   'CNPJ': '67.571.414/0001-41',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Construção Civil',
#   'Segmento de atuação': 'Incorporações',
#   'Patrimônio líquido': '-174609000',
#   'Ativos': '318939000',
#   'Ativo circulante': '171000000',
#   'Dívida bruta': '240114000',
#   'Disponibilidade': '12540000',
#   'Dívida líquida': '227574000',
#   'Valor de mercado': '125307258',
#   'Valor de firma': '352881258',
#   'Número total de papéis': '223762960',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '64.68',
#   'Cotação atual': '0.56',
#   'Mínima 52 semanas': '0.38',
#   'Máxima 52 semanas': '1.33',
#   'Dividend Yield': '-',
#   'Valorização': '-48.15'},
#  {'Papel': 'vivt3',
#   'Empresa': 'TELEFÔNICA BRASIL S.A',
#   'CNPJ': '02.558.157/0001-62',
#   'Setor de atuação': 'Comunicações',
#   'Subsetor de atuação': 'Telecomunicações',
#   'Segmento de atuação': 'Telecomunicações',
#   'Patrimônio líquido': '69092665000',
#   'Ativos': '122372426000',
#   'Ativo circulante': '21094353000',
#   'Dívida bruta': '19747581000',
#   'Disponibilidade': '6027122000',
#   'Dívida líquida': '13720459000',
#   'Valor de mercado': '64092580718',
#   'Valor de firma': '77813039718',
#   'Número total de papéis': '1676938271',
#   'Segmento de listagem': '',
#   'Free float': '25.23',
#   'Cotação atual': '38.22',
#   'Mínima 52 semanas': '35.66',
#   'Máxima 52 semanas': '53.59',
#   'Dividend Yield': '8.00',
#   'Valorização': '-15.03'},
#  {'Papel': 'vlid3',
#   'Empresa': 'VALID SOLUÇÕES S.A.',
#   'CNPJ': '33.113.309/0001-47',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Serviços',
#   'Segmento de atuação': 'Serviços Diversos',
#   'Patrimônio líquido': '1273442000',
#   'Ativos': '3111942000',
#   'Ativo circulante': '1630677000',
#   'Dívida bruta': '1106080000',
#   'Disponibilidade': '381436000',
#   'Dívida líquida': '724644000',
#   'Valor de mercado': '746347740',
#   'Valor de firma': '1470991740',
#   'Número total de papéis': '81836375',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '96.85',
#   'Cotação atual': '9.12',
#   'Mínima 52 semanas': '7.71',
#   'Máxima 52 semanas': '11.87',
#   'Dividend Yield': '2.88',
#   'Valorização': '14.00'},
#  {'Papel': 'vspt3',
#   'Empresa': 'FERROVIA CENTRO-ATLANTICA S.A.',
#   'CNPJ': '00.924.429/0001-75',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Transporte',
#   'Segmento de atuação': 'Transporte Ferroviário',
#   'Patrimônio líquido': '4154751000',
#   'Ativos': '8422794000',
#   'Ativo circulante': '763250000',
#   'Dívida bruta': '619956000',
#   'Disponibilidade': '266076000',
#   'Dívida líquida': '353880000',
#   'Valor de mercado': '712610842',
#   'Valor de firma': '1066490842',
#   'Número total de papéis': '142807803',
#   'Segmento de listagem': '',
#   'Free float': '0.00',
#   'Cotação atual': '4.99',
#   'Mínima 52 semanas': '-',
#   'Máxima 52 semanas': '-',
#   'Dividend Yield': '-',
#   'Valorização': '-'},
#  {'Papel': 'vulc3',
#   'Empresa': 'VULCABRAS/AZALEIA S.A.',
#   'CNPJ': '50.926.955/0001-42',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Tecidos. Vestuário e Calçados',
#   'Segmento de atuação': 'Calçados',
#   'Patrimônio líquido': '1610776000',
#   'Ativos': '2374660000',
#   'Ativo circulante': '1609636000',
#   'Dívida bruta': '360989000',
#   'Disponibilidade': '211959000',
#   'Dívida líquida': '149030000',
#   'Valor de mercado': '2902381242',
#   'Valor de firma': '3051411242',
#   'Número total de papéis': '245756244',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '30.02',
#   'Cotação atual': '11.81',
#   'Mínima 52 semanas': '8.03',
#   'Máxima 52 semanas': '15.27',
#   'Dividend Yield': '3.13',
#   'Valorização': '43.67'},
#  {'Papel': 'vveo3',
#   'Empresa': 'CM HOSPITALAR S.A.',
#   'CNPJ': '12.420.164/0001-57',
#   'Setor de atuação': 'Saúde',
#   'Subsetor de atuação': 'Serv.Méd.Hospit..Análises e Diagnósticos',
#   'Segmento de atuação': 'Serv.Méd.Hospit..Análises e Diagnósticos',
#   'Patrimônio líquido': '2292799000',
#   'Ativos': '8257107000',
#   'Ativo circulante': '4762967000',
#   'Dívida bruta': '2980835000',
#   'Disponibilidade': '1453544000',
#   'Dívida líquida': '1527291000',
#   'Valor de mercado': '4452079482',
#   'Valor de firma': '5979370482',
#   'Número total de papéis': '286123360',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '39.66',
#   'Cotação atual': '15.56',
#   'Mínima 52 semanas': '13.02',
#   'Máxima 52 semanas': '19.40',
#   'Dividend Yield': '2.79',
#   'Valorização': '-6.49'},
#  {'Papel': 'wege3',
#   'Empresa': 'WEG S.A.',
#   'CNPJ': '84.429.695/0001-11',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Máquinas e Equipamentos',
#   'Segmento de atuação': 'Motores . Compressores e Outros',
#   'Patrimônio líquido': '13413944000',
#   'Ativos': '25882424000',
#   'Ativo circulante': '17566996000',
#   'Dívida bruta': '2853828000',
#   'Disponibilidade': '3072450000',
#   'Dívida líquida': '-218622000',
#   'Valor de mercado': '159624003464',
#   'Valor de firma': '159405381464',
#   'Número total de papéis': '4197317998',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '35.30',
#   'Cotação atual': '38.03',
#   'Mínima 52 semanas': '22.62',
#   'Máxima 52 semanas': '40.85',
#   'Dividend Yield': '1.36',
#   'Valorização': '30.73'},
#  {'Papel': 'west3',
#   'Empresa': 'WESTWING COMERCIO VAREJISTA S.A.',
#   'CNPJ': '14.776.142/0001-50',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Produtos Diversos',
#   'Patrimônio líquido': '351390000',
#   'Ativos': '425416000',
#   'Ativo circulante': '276525000',
#   'Dívida bruta': '29702000',
#   'Disponibilidade': '159837000',
#   'Dívida líquida': '-130135000',
#   'Valor de mercado': '118053410',
#   'Valor de firma': '-12081590',
#   'Número total de papéis': '110330290',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '98.56',
#   'Cotação atual': '1.07',
#   'Mínima 52 semanas': '0.86',
#   'Máxima 52 semanas': '3.73',
#   'Dividend Yield': '-',
#   'Valorização': '-61.79'},
#  {'Papel': 'whrl3',
#   'Empresa': 'WHIRLPOOL S.A.',
#   'CNPJ': '59.105.999/0001-86',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Eletrodomésticos',
#   'Patrimônio líquido': '2443415000',
#   'Ativos': '8094272000',
#   'Ativo circulante': '5631916000',
#   'Dívida bruta': '806005000',
#   'Disponibilidade': '1279858000',
#   'Dívida líquida': '-473853000',
#   'Valor de mercado': '7252819263',
#   'Valor de firma': '6778966263',
#   'Número total de papéis': '1502786006',
#   'Segmento de listagem': '',
#   'Free float': '100.00',
#   'Cotação atual': '4.76',
#   'Mínima 52 semanas': '4.36',
#   'Máxima 52 semanas': '6.51',
#   'Dividend Yield': '3.93',
#   'Valorização': '-26.88'},
#  {'Papel': 'whrl4',
#   'Empresa': 'WHIRLPOOL S.A.',
#   'CNPJ': '59.105.999/0001-86',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Eletrodomésticos',
#   'Patrimônio líquido': '2443415000',
#   'Ativos': '8094272000',
#   'Ativo circulante': '5631916000',
#   'Dívida bruta': '806005000',
#   'Disponibilidade': '1279858000',
#   'Dívida líquida': '-473853000',
#   'Valor de mercado': '7252819263',
#   'Valor de firma': '6778966263',
#   'Número total de papéis': '1502786006',
#   'Segmento de listagem': '',
#   'Free float': '100.00',
#   'Cotação atual': '4.97',
#   'Mínima 52 semanas': '4.45',
#   'Máxima 52 semanas': '7.49',
#   'Dividend Yield': '4.14',
#   'Valorização': '-33.64'},
#  {'Papel': 'wizs3',
#   'Empresa': 'WIZ SOLUÇÕES E CORRETAGEM DE SEGUROS S.A.',
#   'CNPJ': '42.278.473/0001-03',
#   'Setor de atuação': 'Financeiro e Outros',
#   'Subsetor de atuação': 'Previdência e Seguros',
#   'Segmento de atuação': 'Corretoras de Seguros',
#   'Patrimônio líquido': '434444000',
#   'Ativos': '1991929000',
#   'Ativo circulante': '357474000',
#   'Dívida bruta': '269683000',
#   'Disponibilidade': '240149000',
#   'Dívida líquida': '29534000',
#   'Valor de mercado': '1114553756',
#   'Valor de firma': '1144087756',
#   'Número total de papéis': '159907282',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '47.07',
#   'Cotação atual': '6.97',
#   'Mínima 52 semanas': '6.30',
#   'Máxima 52 semanas': '9.10',
#   'Dividend Yield': '8.44',
#   'Valorização': '4.97'},
#  {'Papel': 'wlmm3',
#   'Empresa': 'WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.',
#   'CNPJ': '33.228.024/0001-51',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Material de Transporte',
#   'Patrimônio líquido': '577779000',
#   'Ativos': '701948000',
#   'Ativo circulante': '354769000',
#   'Dívida bruta': '9436000',
#   'Disponibilidade': '97591000',
#   'Dívida líquida': '-88155000',
#   'Valor de mercado': '754142403',
#   'Valor de firma': '665987403',
#   'Número total de papéis': '36414670',
#   'Segmento de listagem': '',
#   'Free float': '15.11',
#   'Cotação atual': '21.50',
#   'Mínima 52 semanas': '19.44',
#   'Máxima 52 semanas': '31.61',
#   'Dividend Yield': '6.87',
#   'Valorização': '-27.39'},
#  {'Papel': 'wlmm4',
#   'Empresa': 'WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.',
#   'CNPJ': '33.228.024/0001-51',
#   'Setor de atuação': 'Bens Industriais',
#   'Subsetor de atuação': 'Comércio',
#   'Segmento de atuação': 'Material de Transporte',
#   'Patrimônio líquido': '577779000',
#   'Ativos': '701948000',
#   'Ativo circulante': '354769000',
#   'Dívida bruta': '9436000',
#   'Disponibilidade': '97591000',
#   'Dívida líquida': '-88155000',
#   'Valor de mercado': '754142403',
#   'Valor de firma': '665987403',
#   'Número total de papéis': '36414670',
#   'Segmento de listagem': '',
#   'Free float': '15.11',
#   'Cotação atual': '20.05',
#   'Mínima 52 semanas': '19.81',
#   'Máxima 52 semanas': '39.46',
#   'Dividend Yield': '5.19',
#   'Valorização': '-46.06'},
#  {'Papel': 'yduq3',
#   'Empresa': 'ESTACIO PARTICIPACOES S.A.',
#   'CNPJ': '08.807.432/0001-10',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Diversos',
#   'Segmento de atuação': 'Serviços Educacionais',
#   'Patrimônio líquido': '3137431000',
#   'Ativos': '9881786000',
#   'Ativo circulante': '2740583000',
#   'Dívida bruta': '5636491000',
#   'Disponibilidade': '1467391000',
#   'Dívida líquida': '4169100000',
#   'Valor de mercado': '3013616297',
#   'Valor de firma': '7182716297',
#   'Número total de papéis': '309088851',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '95.77',
#   'Cotação atual': '9.75',
#   'Mínima 52 semanas': '9.17',
#   'Máxima 52 semanas': '22.75',
#   'Dividend Yield': '1.30',
#   'Valorização': '-47.75'},
#  {'Papel': 'zamp3',
#   'Empresa': 'ZAMP S.A.',
#   'CNPJ': '13.574.594/0001-96',
#   'Setor de atuação': 'Consumo Cíclico',
#   'Subsetor de atuação': 'Hoteis e Restaurantes',
#   'Segmento de atuação': 'Restaurante e Similares',
#   'Patrimônio líquido': '1456994000',
#   'Ativos': '3994258000',
#   'Ativo circulante': '998190000',
#   'Dívida bruta': '1077977000',
#   'Disponibilidade': '548661000',
#   'Dívida líquida': '529316000',
#   'Valor de mercado': '1445616097',
#   'Valor de firma': '1974932097',
#   'Número total de papéis': '275355447',
#   'Segmento de listagem': 'Novo Mercado',
#   'Free float': '98.27',
#   'Cotação atual': '5.25',
#   'Mínima 52 semanas': '4.46',
#   'Máxima 52 semanas': '8.80',
#   'Dividend Yield': '-',
#   'Valorização': '-2.96'}]

# %% [markdown]
# ## Criando o Dataframe

# %%
df_statusinvest = pd.DataFrame(lista_consolidada)

# %%
df_statusinvest.head()
# Out:
#    Papel                                            Empresa  \
# 0  aalr3                 CENTRO DE IMAGEM DIAGNOSTICOS S.A.
# 1  abcb4                                BCO ABC BRASIL S.A.
# 2  abev3                                         AMBEV S.A.
# 3  aeri3  AERIS IND. E COM. DE EQUIP. GERACAO DE ENERGIA...
# 4  aesb3                            AES BRASIL ENERGIA S.A.
#
#                  CNPJ     Setor de atuação  \
# 0  42.771.949/0001-35                Saúde
# 1  28.195.667/0001-06  Financeiro e Outros
# 2  07.526.557/0001-00  Consumo não Cíclico
# 3  12.528.708/0001-07     Bens Industriais
# 4  37.663.076/0001-07    Utilidade Pública
#
#                         Subsetor de atuação  \
# 0  Serv.Méd.Hospit..Análises e Diagnósticos
# 1                Intermediários Financeiros
# 2                                   Bebidas
# 3                   Máquinas e Equipamentos
# 4                          Energia Elétrica
#
#                         Segmento de atuação Patrimônio líquido        Ativos  \
# 0  Serv.Méd.Hospit..Análises e Diagnósticos         1145368000    2573833000
# 1                                    Bancos         5070725000   52140478000
# 2                  Cervejas e Refrigerantes        90178032000  142063954000
# 3                 Máq. e Equip. Industriais          942087000    3459015000
# 4                          Energia Elétrica         4175175000   15104672000
#
#   Ativo circulante Dívida bruta  ... Valor de mercado Valor de firma  \
# 0        457827000    808798000  ...       2518454053     3087062053
# 1       4297215000            -  ...       4291190440     4291190440
# 2      41556965000   2980480000  ...     225543105306   209463715306
# 3       2285013000   1573577000  ...        819848398     1537033398
# 4       4091868000   7893505000  ...       5573846900    10011969900
#
#   Número total de papéis Segmento de listagem Free float Cotação atual  \
# 0              118292816         Novo Mercado      35.52         21.29
# 1              226090118              Nível 2      29.88         18.98
# 2            15750216851                           27.85         14.32
# 3              766213456         Novo Mercado      29.64          1.07
# 4              601927311         Novo Mercado      52.37          9.26
#
#   Mínima 52 semanas Máxima 52 semanas Dividend Yield Valorização
# 0             12.85             21.60              -       65.68
# 1             14.47             22.29           7.36       30.00
# 2             12.47             16.03           5.32        2.95
# 3              0.88              6.54           1.93      -81.83
# 4              9.05             12.06           1.16       -7.12
#
# [5 rows x 22 columns]

# %%
df_statusinvest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Papel                   459 non-null    object
#  1   Empresa                 459 non-null    object
#  2   CNPJ                    459 non-null    object
#  3   Setor de atuação        459 non-null    object
#  4   Subsetor de atuação     459 non-null    object
#  5   Segmento de atuação     459 non-null    object
#  6   Patrimônio líquido      459 non-null    object
#  7   Ativos                  459 non-null    object
#  8   Ativo circulante        459 non-null    object
#  9   Dívida bruta            459 non-null    object
#  10  Disponibilidade         459 non-null    object
#  11  Dívida líquida          459 non-null    object
#  12  Valor de mercado        459 non-null    object
#  13  Valor de firma          459 non-null    object
#  14  Número total de papéis  459 non-null    object
#  15  Segmento de listagem    459 non-null    object
#  16  Free float              459 non-null    object
#  17  Cotação atual           459 non-null    object
#  18  Mínima 52 semanas       459 non-null    object
#  19  Máxima 52 semanas       459 non-null    object
#  20  Dividend Yield          459 non-null    object
#  21  Valorização             459 non-null    object
# dtypes: object(22)
# memory usage: 79.0+ KB

# %%
df_statusinvest.to_csv('dados_empresas_statsusinvest.csv', sep = ';', encoding = 'UTF-8', index = False)
